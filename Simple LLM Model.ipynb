# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm=ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash",
    google_api_key = "AIzaSyCm1cvd9FIV52Z9C0iikRvLTdWV_Nzhvlc"
)

# %%
prompt=ChatPromptTemplate.from_template(
    """you are XL operation Agent so you have to create only formula based on {question}
    and don't add any extra simble like ',/and exctra you should genarate only formula,the output will be only formula no any other thing
    and another importent thing that is ,if the question is not related to XL operation you should reply for that
    questions like 'this is not XL formula related question' """
)

# %%
chain = prompt | llm

# %%
Questions = input("Ask Your Question ...")
respons = chain.invoke(Questions)
# Out:
# Ask Your Question ... what is AI?

# %%
print(respons.content)
# Out:
# this is not XL formula related question
